# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkateshyakkala007/Statistics/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import binom

# %%
binom.pmf(n=10, p=1/4, k = 2)
# Out:
# 0.28156757354736334

# %%
(131 + 150 + 140+ 142 + 152)/5
# Out:
# 143.0

# %%
( (131-143)**2 +  (150-143)**2 + (140-143)**2 + (142-143)**2 +  (152-143)**2 ) / 4
# Out:
# 71.0

# %%
#  simple random sampling


# np.random.choice()

# %%
import numpy as np

# %%
np.random.random()
# Out:
# 0.3351053928214971

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate random data following a uniform distribution
data = np.random.uniform(1, 7, 100000)  # 100000 samples from a uniform distribution between 1 and 6

# Create a histogram
plt.hist(data, bins=6, edgecolor='black', align='mid', rwidth=0.8, density=True, color='skyblue')

# Set labels and title
plt.xlabel('Outcome')
plt.ylabel('Probability')
plt.title('Histogram of a Uniform Distribution (Die Roll Simulation)')

# Show the plot
plt.grid(True)
plt.show()
